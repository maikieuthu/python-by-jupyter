# %%
from PIL import Image
mac =Image.open("fruit_pic.jpg")
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac.size
# Out:
# (275, 183)

# %%
mac.filename
# Out:
# 'fruit_pic.jpg'

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
#CROPPING IMAGES

# %%
#TOP SIDE
x=0
y=0
w=275
h=183
mac.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x1E1D2FBE280>

# %%
#BOTTOM SIDE(left <= x < right, top <= y < bottom)(275, 183)left top right bottom
x=0
y=150
w=275
h=183
mac.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=275x33 at 0x1E1D30873A0>
